# %%
base_dir = r"D:\aiproject\chest_xray"

train_dir = base_dir + r"\train"
test_dir  = base_dir + r"\test"
val_dir   = base_dir + r"\val"

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)
test_datagen  = ImageDataGenerator(rescale=1./255)
val_datagen   = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)

val_data = val_datagen.flow_from_directory(
    val_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)

test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')   # pneumonia or normal
])

model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = Sequential([
#       2     Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
#       3     MaxPooling2D(2,2),
#       4
#       5     Conv2D(64, (3,3), activation='relu'),
#       6     MaxPooling2D(2,2),
#       7
#       8     Conv2D(128, (3,3), activation='relu'),
#       9     MaxPooling2D(2,2),
#      10
#      11     Flatten(),
#      12     Dense(128, activation='relu'),
#      13     Dropout(0.5),
#      14     Dense(1, activation='sigmoid')   # pneumonia or normal
#      15 ])
#      17 model.compile(
#      18     optimizer=Adam(learning_rate=0.0005),
#      19     loss='binary_crossentropy',
#      20     metrics=['accuracy'])
#
# NameError: name 'Sequential' is not defined

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=20
)
# Out:
# Epoch 1/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 79s 475ms/step - accuracy: 0.7981 - loss: 0.4469 - val_accuracy: 0.6250 - val_loss: 1.0886
# Epoch 2/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 76s 465ms/step - accuracy: 0.8867 - loss: 0.2716 - val_accuracy: 0.9375 - val_loss: 0.4064
# Epoch 3/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 80s 492ms/step - accuracy: 0.9132 - loss: 0.2186 - val_accuracy: 0.7500 - val_loss: 0.5531
# Epoch 4/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 78s 480ms/step - accuracy: 0.9187 - loss: 0.2037 - val_accuracy: 0.7500 - val_loss: 1.1536
# Epoch 5/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 78s 477ms/step - accuracy: 0.9185 - loss: 0.2078 - val_accuracy: 0.8125 - val_loss: 0.5031
# Epoch 6/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 80s 487ms/step - accuracy: 0.9300 - loss: 0.1865 - val_accuracy: 0.9375 - val_loss: 0.3020
# Epoch 7/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 501ms/step - accuracy: 0.9316 - loss: 0.1780 - val_accuracy: 0.7500 - val_loss: 0.6440
# Epoch 8/20
# ...

# %%
test_loss, test_acc = model.evaluate(test_data)
print("Test Accuracy:", test_acc)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 452ms/step - accuracy: 0.8782 - loss: 0.3754
# Test Accuracy: 0.8782051205635071

# %%
model.save(r"D:\xraypneumoniadetector\pneumonia_model2.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf

from tensorflow.keras.models import load_model

import numpy as np

from tensorflow.keras.preprocessing import image





model_path = r"D:\xraypneumoniadetector\pneumonia_model2.h5"



model = load_model(model_path)



def predict_xray(img_path):

    img = image.load_img(img_path, target_size=(150,150))

    img_array = image.img_to_array(img) / 255.0

    img_array = np.expand_dims(img_array, axis=0)             

    prediction = model.predict(img_array)[0][0]

    if prediction > 0.5:

        print("Prediction: PNEUMONIA")

    else:

        print("Prediction: NORMAL")

predict_xray(r"D:\aiproject\chest_xray\test\PNEUMONIA\person1_virus_6.jpeg")
# Out:
# C:\Users\HP\anaconda3\envs\pneumoniadetector\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# Prediction: PNEUMONIA

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\HP\anaconda3\envs\pneumoniadetector\python.exe

# %%
# Out:
# 1.16.3
